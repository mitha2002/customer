# %%
import pandas as pd

# %%
customer=["ravi","maran","kavitha","kalai","kumar","barathi","sakthi","abi","mani","kani","ram","ramesh","karan","dhevi","shalini","parkavi","revathi"]
amount=[10000,15000,20000,14000,24000,25000,130000,50000,40000,60000,18000,160000,140000,9000,16000,27000,30000]
customer_id=[101,102,103,104,105,106,107,108,109,110,112,113,114,115,116,117,118]

# %%
data=pd.DataFrame({"customer":customer,"amount":amount,"customer_id":customer_id})

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      mani   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
customer[2:4]
# Out:
# ['kavitha', 'kalai']

# %%
data.customer
# Out:
# 0        ravi
# 1       maran
# 2     kavitha
# 3       kalai
# 4       kumar
# 5     barathi
# 6      sakthi
# 7         abi
# 8        mani
# 9        kani
# 10        ram
# 11     ramesh
# 12      karan
# 13      dhevi
# 14    shalini
# 15    parkavi
# 16    revathi
# Name: customer, dtype: object

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      mani   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      mani   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.replace({'mani':'ravi'},inplace=True)

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.rename(columns={"amonut":"salary"},inplace=True)

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.rename(columns={"amonut":"salary"},inplace=True)

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.columns
# Out:
# Index(['customer', 'amount', 'customer_id'], dtype='object')

# %%
data.rename(columns={"amonut":"Amount"},inplace=True)

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.tail(12)
# Out:
#    customer  amount  customer_id
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118

# %%
data.head(6)
# Out:
#   customer  amount  customer_id
# 0     ravi   10000          101
# 1    maran   15000          102
# 2  kavitha   20000          103
# 3    kalai   14000          104
# 4    kumar   24000          105
# 5  barathi   25000          106

# %%
data
# Out:
#    customer  amount  customer_id
# 0      ravi   10000          101
# 1     maran   15000          102
# 2   kavitha   20000          103
# 3     kalai   14000          104
# 4     kumar   24000          105
# 5   barathi   25000          106
# 6    sakthi  130000          107
# 7       abi   50000          108
# 8      ravi   40000          109
# 9      kani   60000          110
# 10      ram   18000          112
# 11   ramesh  160000          113
# 12    karan  140000          114
# 13    dhevi    9000          115
# 14  shalini   16000          116
# 15  parkavi   27000          117
# 16  revathi   30000          118
